# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Shreenidhi H

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project aims to do the Exploratory Data Analysis (EDA) on a Airbnb booking data analysis. The objectives of the analysis is mentioned in business objective section below. I've created 16 plots  using UBM stratregy. (Univariate, Bi-Variate and Multi variate analysis). The explorations and insights gained from the charts are mentioned below each of them and the solution to the business objectives from the analysis is mentioned in the last section.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# - To find out the regions of more bookings, and regions of less bookings and revenue.
# - To increase the bookings of the rooms in the regions of less revenue
# - To find the relevant factors and causes

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
bookings = pd.read_csv(r"Airbnb NYC 2019.csv")
bookings.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset First View

# %%
bookings.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(bookings.shape) # print (row no, column no)
# dataset has 48895 rows and 16 columns
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
bookings[bookings.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
bookings.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
bookings = bookings[bookings['availability_365'] != 0]
bookings = bookings[bookings['price'] != 0]
bookings = bookings[bookings['reviews_per_month'] != 0]
bookings = bookings.dropna()
bookings =bookings.drop(columns =['last_review'])
print(len(bookings))
# Out:
# 26138

# %%
sns.heatmap(bookings.isnull(),cbar =False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Host name is missing in some of the dataset. it is less than 1 percent of the dataset it can be ignored.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
bookings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
bookings.describe(include=['int','float'])
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.613800e+04  2.613800e+04  26138.000000  26138.000000  26138.000000
# mean   1.932429e+07  7.459055e+07     40.727492    -73.947739    149.945711
# std    1.121168e+07  8.263401e+07      0.056934      0.051474    198.859861
# min    2.539000e+03  2.571000e+03     40.506410    -74.244420     10.000000
# 25%    9.458787e+06  7.365834e+06     40.687050    -73.982420     70.000000
# 50%    2.079406e+07  3.528477e+07     40.721680    -73.953045    109.000000
# 75%    2.951217e+07  1.316471e+08     40.763030    -73.929242    175.000000
# max    3.645581e+07  2.738417e+08     40.913060    -73.712990   9999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    26138.000000       26138.000000       26138.000000
# mean         6.585278          38.181613           1.810199
# std         19.606603          54.358978           1.805818
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - id -                                  Unique Booking id for each of the booking made through AirBnb.
# - name -                                Name of building listed in AirBnB for rent.
# - host_id -                             Id given to the person booking through Airbnb
# - host_name -                           Name of the person renting
# - neighbourhood_group                   Area  of main locality
# - neighbourhood                         Area  of sub -locality
# - latitude                              Latitude of the location
# - longitude                             Longitude of the location
# - room_type                             Type of room
# - price                                 Price of the room
# - minimum_nights                        Minimum nights of stay
# - number_of_reviews                     No of reviews provided
# - last_review                           The time of last review
# - reviews_per_month                     The number fo review provided in month
# - calculated_host_listings_count        Host_listings
# - availability_365                      Availability pf the hotel in the year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

#for column in list(bookings.columns):
   # print(column, len(bookings[column].unique()))
summary = pd.DataFrame([(column, len(bookings[column].unique()),bookings[column].dtype) for column in list(bookings.columns)],columns =['column_name','Unique_len','dtype'])
summary
# Out:
#                        column_name  Unique_len    dtype
# 0                               id       26138    int64
# 1                             name       25863   object
# 2                          host_id       18935    int64
# 3                        host_name        7362   object
# 4              neighbourhood_group           5   object
# 5                    neighbourhood         217   object
# 6                         latitude       14646  float64
# 7                        longitude       12310  float64
# 8                        room_type           3   object
# 9                            price         563    int64
# 10                  minimum_nights          84    int64
# 11               number_of_reviews         387    int64
# 12               reviews_per_month         929  float64
# 13  calculated_host_listings_count          47    int64
# 14                availability_365         365    int64

# %%
summary[summary['dtype'] == 'int64']
# Out:
#                        column_name  Unique_len  dtype
# 0                               id       26138  int64
# 2                          host_id       18935  int64
# 9                            price         563  int64
# 10                  minimum_nights          84  int64
# 11               number_of_reviews         387  int64
# 13  calculated_host_listings_count          47  int64
# 14                availability_365         365  int64

# %%
summary[summary['dtype'] == 'float64']
# Out:
#           column_name  Unique_len    dtype
# 6            latitude       14646  float64
# 7           longitude       12310  float64
# 12  reviews_per_month         929  float64

# %%
summary[summary['dtype'] == 'object']
# Out:
#            column_name  Unique_len   dtype
# 1                 name       25863  object
# 3            host_name        7362  object
# 4  neighbourhood_group           5  object
# 5        neighbourhood         217  object
# 8            room_type           3  object

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
bookings = bookings.drop(columns =['host_name'])
bookings.shape
# Out:
# (26138, 14)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
bookings.columns
# Out:
# Index(['id', 'name', 'host_id', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# ##### Chart 1 -Pairplot

# %%
sns.pairplot(bookings[['price','minimum_nights','number_of_reviews','reviews_per_month','availability_365']],corner =True)

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [raw]
# Pairplots are a great way to find the relationship between any 2 independent numcerical variable visually. It is easer to visualise it as a grid when there are series of numerical variables in a dataframe

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [raw]
# - Number of reviews and reviews_per_month are linearly correlated. Hence, one of the independent bvariables can be considered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - These continuous numerical variables need to converted to discrete range to gain more insights

# %% [markdown]
# #### Chart - 2 -Which neighbourhood group has more listings in Airbnb ?

# %%
neighbourhood = pd.DataFrame(bookings.groupby(by ='neighbourhood_group')['name'].apply(lambda x: len(x)))
neighbourhood
# Out:
#                       name
# neighbourhood_group
# Bronx                  754
# Brooklyn             10653
# Manhattan            10810
# Queens                3634
# Staten Island          287

# %%
# Chart - 1 visualization code
fig,ax =plt.subplots(ncols =2,figsize =(12,6))

bookings['neighbourhood_group'].value_counts().plot(kind ='line',marker ='o',ms =3,color ='black',lw =0.8,
                                                    ax=ax[0],subplots=True)
ax[0].set_xlabel('Neighbourhood Group',weight ='bold',size =10)
ax[0].set_ylabel('Count of AirBnb Listings',weight ='bold',size =10)
ax[0].set_title('Neighbourhood Group wise - Count of listing in Airbnb',color ='black',size =11,weight='bold')#,font ='Calibri')

bookings['neighbourhood_group'].value_counts().plot(kind ='pie',ax=ax[1],subplots=True,
                                                    autopct='%.0f%%',explode=[0, 0, 0, 0.1, 0.3] )
ax[1].set_xlabel('Neighbourhood Group',weight ='bold',size =10)
ax[1].set_ylabel('Count as %  of AirBnb Listings',weight ='bold',size =10)
ax[1].set_title('Neighbourhood Group wise - Count displayed as % of listing in Airbnb',color ='black',size =11,weight='bold')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line Plot is chosen as it is covenient to see and compare the numbers of different categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan, Brooklyn are the locations where majority of booking are done. Followed by Queens, which is one-fourth of their bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Only 2 locations contribute to more than 90 percent of the bookings (Manhattan & Brooklyn).Hence, focus need to be given to improve listings in Queens, States Island and Bronx .

# %% [markdown]
# #### Chart - 3 - Which neighbourhood has more bookings?

# %%
# Chart - 2 visualization code
hotel_area = pd.DataFrame(bookings.groupby(by ='neighbourhood')['name'].apply(lambda x: len(x)))
hotel_area = hotel_area.sort_values(by =['name'], ascending =False).head(25)
hotel_area
# Out:
#                            name
# neighbourhood
# Bedford-Stuyvesant         2208
# Williamsburg               1785
# Harlem                     1507
# Bushwick                   1214
# Hell's Kitchen             1191
# Upper East Side             896
# Upper West Side             858
# East Village                814
# Crown Heights               796
# Midtown                     698
# East Harlem                 650
# Chelsea                     532
# Greenpoint                  490
# Astoria                     469
# Washington Heights          467
# Lower East Side             453
# Financial District          397
# East Flatbush               369
# West Village                353
# Flushing                    322
# Flatbush                    313
# Clinton Hill                291
# Prospect-Lefferts Gardens   290
# Long Island City            290
# Park Slope                  255

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2, shared_yaxes=True,specs=[[{'type':'bar'}, {'type':'domain'}]])
fig.add_trace(
    go.Bar(x=list(hotel_area.index.values), y=hotel_area['name'], textposition='auto',text=hotel_area['name']),
    1,1)
fig.add_trace(go.Pie(labels=list(hotel_area.index.values), values=hotel_area['name'], name="-"),
              1, 2)

fig.update_layout(title_text='Neighbourhood wise - Count of listing in Airbnb')

fig.show()

# %%
fig = plt.figure() 
fig, ax = plt.subplots(figsize=(12,6),layout='constrained')
bars =plt.bar(list(hotel_area.index.values),hotel_area['name'])
plt.xlabel('Neighbourhood',weight ='bold')
plt.ylabel('Count of Airbnb Listings',weight ='bold')
plt.title('Neighbourhood wise-Count of Airbnb listings',weight ='bold',size=12)
plt.xticks(rotation=90)
for bar in bars:
    height = bar.get_height()
    plt.annotate(f"{height}", xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 1), # Adjust the position of the label
                 textcoords="offset points",
                 ha='center', va='bottom')
    plt.annotate(f"{round(height/len(bookings),2)*100}%", xy=(bar.get_x() + bar.get_width() / 2, height/2),
                 xytext=(0, 1), # Adjust the position of the label
                 textcoords="offset points",
                 ha='center', va='bottom')
                       
#plt.tight_layout()                       
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot is well suited to visual counts of the categorical variable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Williamsburg (3920),Bedford-Stuyvesant(3714),Harlem	(2658), Bushwick (2465) together contributes to nearly 25 % of the bookings. The top 13 locations from Williamsburg to Chelsea in the chart contributes to nearly 50 % (25k) of the bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Only top 25 locations contribute more than 1% of bookings. Rest 196 locations have been ignored. In teh top 25 , only top 13 locations contribute to 50 percent bookings, rest 12 locations need to be given importance to improve bookings

# %% [markdown]
# #### Chart - 4  What are the neighbourhood in each neighbourhood group ? How many bookings were done in each of them?

# %%
bookings['count_booking'] =1

# %%
fig = px.sunburst(bookings, path=['neighbourhood_group','neighbourhood'], values='count_booking')
fig.show()
# Out:
# <div>                            <div id="8c8be47f-bbd0-4db4-b77e-fdc13aa7502e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c8be47f-bbd0-4db4-b77e-fdc13aa7502e")) {                    Plotly.newPlot(                        "8c8be47f-bbd0-4db4-b77e-fdc13aa7502e",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_booking=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Bronx/Allerton","Staten Island/Arden Heights","Staten Island/Arrochar","Queens/Arverne","Queens/Astoria","Brooklyn/Bath Beach","Manhattan/Battery Park City","Brooklyn/Bay Ridge","Queens/Bay Terrace","Bronx/Baychester","Queens/Bayside","Queens/Bayswater","Brooklyn/Bedford-Stuyvesant","Quee
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Sunburst charts helps to get a clear visualisation of the main group (neighbourhood_group) bookings also sub-groups ( neighbourhood) bookings And also. allows to visualise a data for a paticular group alone say, Manhattan by cliking on it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5  Does the bookings depend on the room_type?

# %%
bookings['room_type'] = bookings['room_type'].map({'Private room':'Private room', 'Entire home/apt' :'Entire Home', 'Shared room':'Shared room'})

# %%
rt_count = list(bookings['room_type'].value_counts())
print(rt_count)
# Out:
# [13702, 11773, 663]

# %%
# Chart - 4 visualization code
fig,ax =plt.subplots(figsize =(6,4))
sns.countplot(data =bookings , x ='room_type')
plt.xlabel('Room Types',size =10,weight ='bold')
plt.ylabel('Count of Airbnb Bookings',size =10,weight ='bold')
plt.title('Count of Airbnb Bookings -Based on Room Types',size =10,weight ='bold')
plt.annotate( rt_count[0], xy=(-0.2, 15000),xytext=(-0.2, 3000), size=12)
plt.annotate( rt_count[1], xy=(0.8, 15000), xytext=(0.8, 3000), size=12)
plt.annotate( rt_count[2], xy=(1.7, 15000), xytext=(1.7, 3000), size=12)
plt.show()

fig,ax =plt.subplots(figsize =(6,4))
rt = sns.countplot(bookings , x ='room_type',hue ='neighbourhood_group')
plt.xlabel('Room Types',size =10,weight ='bold')
plt.ylabel('Count of Airbnb Bookings',size =10,weight ='bold')
plt.title('Count of Airbnb Bookings -Based on Room Types & Neighbourhood_group',size =10,weight ='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart gives a better represention of categorical data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Although, the total bookings in the region Manhattana and Brooklyn is high. And the total bookings is private room and entire home is high.It is observed that Brooklyn has more private room bookings. Manhattan has more Entire home room type bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Shared Room type bookings is less for any neighbourhood. Need to find out the reasons and address it

# %% [markdown]
# #### Chart - 6 How does the price range affcet the bookings?

# %%
# Chart - 5 visualization code

# removing the outliers based on inter Quartile Region (IQR)
iqr = bookings['price'].quantile(0.75) - bookings['price'].quantile(0.25)
lower_bound = bookings['price'].quantile(0.25) - 1.5 * iqr
upper_bound = bookings['price'].quantile(0.75) + 1.5 * iqr
bookings['price'] = bookings['price'][((bookings['price'] >= lower_bound) & (bookings['price'] <= upper_bound))]

# %%
print(bookings['price'].isnull().sum())
bookings = bookings.query("price.notnull()")
# Out:
# 1607

# %%
print(bookings.shape)
print(bookings['price'].isnull().sum())
# Out:
# (24531, 15)
# 0

# %%
fig,axes = plt.subplots(ncols =2,figsize =(12,5))

## Histogram Plotting 
sns.histplot(bookings['price'],ax =axes[0])
axes[0].set_xlabel('Price Range',weight ='bold',size =10)
axes[0].set_ylabel('Booking Count',weight ='bold',size =10)
axes[0].set_title('Histogram of price range of Airbnb hotel bookings'.title(),weight ='bold',size =10)

#### Binning the numerical values after seeing the histogram 
print(bookings['price'].isnull().sum())
bookings['price'] = pd.cut(bookings['price'],bins =[0,50,100,150,200,250,300,350])
print(bookings['price'].isnull().sum())

#### Booking count in each bin
sns.countplot(data=bookings, x='price', ax=axes[1])
axes[1].set_xlabel('Price Range', weight='bold', size=10)
axes[1].set_ylabel('Booking Count',weight ='bold',size =10)
axes[1].bar_label(axes[1].containers[0], fontsize=10);
plt.xticks(rotation=90)
plt.show()
# Out:
# 0
# 0

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are a great way to visualise the distribution of data for a continuous numerical data and to check for outliers. once, this is checked for the price range, The data is biined to visualise booking in increase in each of 50 rupees.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is observed that the booking decreased with the increase in price. however, the least price range of (0,50] had bookings in same range as (150,200]  price. Other facilities aling with the price range need to identified

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# People are wiiling to pay a premium price. it is found out from 2214 people paying a range of (200,250] .Hence other facilities need to considered to bring in more people afford a premium range rooms

# %% [markdown]
# #### Chart - 7 Does the number reviews provided affect the number of bookings?

# %%
# Chart - 6 visualization code

def iqr_outlier_removal(df):
    iqr = df.quantile(0.75) - df.quantile(0.25)
    lower_bound = df.quantile(0.25) - 1.5 * iqr
    upper_bound = df.quantile(0.75) + 1.5 * iqr
    df = df[((df >= lower_bound) & (df <= upper_bound))]
    return df

def percentile_outlier_removal(df1,lb,ub):
    lower_bound = lb
    upper_bound = ub
    q_lower = df1.quantile(lower_bound)
    q_upper = df1.quantile(upper_bound)
    
    ### use for single column of a dataframe as input
    df1 = df1[((df1 >= q_lower) & (df1 <= q_upper))]
    ### use for multiple columns of a dataframe as input
    #df1 = df1[((df1 >= q_lower) & (df1 <= q_upper)).all(axis=1)]
    return df1


def eyetest_outlier_removal(df1):
    age_mean = df1.mean()
    age_std = df1.std()
    age_threshold = age_mean + 2 * age_std

    #outliers_eye_test = df1[df1> age_threshold]
    df1 =df1[df1 < age_threshold ]
    return df1

# %%
### Outlier removal in average reviews per month 
#bookings['reviews_per_month'] = percentile_outlier_removal(bookings['reviews_per_month'],0.1,0.90)
#bookings['reviews_per_month']
#bookings['number_of_reviews']  =percentile_outlier_removal(bookings['number_of_reviews'] ,0.1,0.90)

#bookings['reviews_per_month'] = eyetest_outlier_removal(bookings['reviews_per_month'])
#bookings['number_of_reviews']  = eyetest_outlier_removal(bookings['number_of_reviews'])

bookings['reviews_per_month'] = iqr_outlier_removal(bookings['reviews_per_month'])
#bookings['number_of_reviews']  = iqr_outlier_removal(bookings['number_of_reviews'])

# %%
print(bookings['reviews_per_month'].isnull().sum())
bookings  = bookings.query('reviews_per_month.notnull()')

print(bookings.shape)
print(bookings['reviews_per_month'].isnull().sum())
# Out:
# 670
# (23861, 15)
# 0

# %%
print(bookings.shape)
print(bookings['reviews_per_month'].isnull().sum())
# Out:
# (23861, 15)
# 0

# %%
pd.cut(bookings['reviews_per_month'],bins =[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5]).isnull().sum()
# Out:
# 689

# %%
fig,axes = plt.subplots(ncols =2,figsize =(12,5))

## Histogram Plotting 
sns.histplot(bookings['reviews_per_month'],ax =axes[0])
axes[0].set_xlabel('Reviews_per_Month',weight ='bold')
axes[0].set_ylabel('Count of AirBnb Bookings',weight ='bold')
axes[0].set_title('Histogram of Reviews_Per_Month of Airbnb hotel bookings'.title(),weight ='bold',size =10)

#Binning the variables
#bookings['reviews_per_month'] =pd.cut(bookings['reviews_per_month'],bins =[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5])
print(bookings['reviews_per_month'].isnull().sum())
bookings['reviews_per_month'] =pd.cut(bookings['reviews_per_month'],bins =[0,1,2,3,4,5,6,7])
print(bookings['reviews_per_month'].isnull().sum())

## Count plot of variables
sns.countplot(data= bookings, x = 'reviews_per_month')
axes[1].set_xlabel('Reviews_per_Month',weight ='bold')
axes[1].set_ylabel('Count of AirBnb Bookings',weight ='bold')
axes[1].bar_label(axes[1].containers[0], fontsize=10);
plt.xticks(rotation=90)
plt.show()
# Out:
# 0
# 0

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are a great way to visualise the distribution of data for a continuous numerical data and to check for outliers. Bar graphs give better visualisation for binned numerical data that act as categorical data type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Booking and reviews seems to be reversely correlated in contrast. The higher the number of review per month, lesser is the booking and viceversa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Only the count of reviews may not be a good number to understand the number of bookings. More insights into the positive and negative reviews will be helpful

# %% [markdown]
# #### Chart - 8 What is the most common duration of stay?

# %%
# Chart - 8 visualization code
plt.figure(figsize =(6,4))
fig,ax =plt.subplots()
iqr_outlier_removal(bookings['minimum_nights']).value_counts().plot(kind ='bar')
plt.xlabel('Minimum_Nights of Stay',weight ='bold',size=10)
plt.ylabel('Number of Bookings',weight ='bold',size=10)
plt.title('Duration of Stay against Number of Bookings',weight ='bold',size=10)
plt.bar_label(ax.containers[0], fontsize=10)
plt.show()

# %%
bookings['minimum_nights'] = iqr_outlier_removal(bookings['minimum_nights'])

# %%
print(bookings['minimum_nights'].isnull().sum())
print(bookings.shape)

bookings =bookings.query('minimum_nights.notnull()')
print(bookings.shape)
# Out:
# 3456
# (23861, 15)
# (20405, 15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are suited better to visualise the discrete numerical variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1-3 nights is the common duration of bookings in Airnbnb

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, in planning the vacancy of rooms and for accomdating teh availability

# %% [markdown]
# ####  Chart - 9  Does the availibility of rooms affect the bookings

# %%
len(bookings)
# Out:
# 20405

# %%
len((bookings['availability_365']).unique())
len(iqr_outlier_removal(bookings['availability_365']).unique())
# Out:
# 365

# %%
# Chart - 8 visualization code
#iqr_outlier_removal(bookings['availability_365']).value_counts().plot(kind ='bar')
fig,axes = plt.subplots(ncols =2,figsize =(12,5))

sns.histplot(iqr_outlier_removal(bookings['availability_365']),ax =axes[0])
axes[0].set_xlabel('Availability in Days',weight ='bold')
axes[0].set_ylabel('Frequency of Availability',weight ='bold')
axes[0].set_title('Histogram of Availability(Days)',weight ='bold')

print(bookings['availability_365'].isnull().sum())
bookings['availability_365'] =pd.cut(bookings['availability_365'],bins =[0,30,60,90,120,150,180,210,240,270,300,330,366],
                                    labels =['1M','2M','3M','4M','5M','6M','7M','8M','9M','10M','11M','12M'],
                                    include_lowest =True)
print(bookings['availability_365'].isnull().sum())


sns.countplot(data= bookings, x = 'availability_365',ax =axes[1])
axes[1].set_title('Bar Plot of Availability(Months)',weight ='bold')
axes[1].set_xlabel('No of Months -Available',weight ='bold')
axes[1].set_ylabel('Count of No of listings',weight ='bold')
axes[1].bar_label(axes[1].containers[0], fontsize=10);
plt.show()
# Out:
# 0
# 0

# %%
print(len(bookings))
print(bookings['availability_365'].isnull().sum())
# Out:
# 20405
# 0

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are suitable to visualise the discrete numerical variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of teh listings are available for 1 month, followed by the rooms available throughout the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Try to get more listings of room in the important regions like Manhattan , brooklyn that rent for a month, or throughout the year

# %% [markdown]
# #### Chart - 10  Do any interrelations between neighbourhood group and hotel availability together affect the number of booking?

# %%
# Chart - 9 visualization code

# %%
availability = pd.DataFrame(bookings.groupby(['availability_365','neighbourhood_group'])['id'].apply(lambda x: len(x))).reset_index()
print(sum(availability['id']))
availability.head()
# Out:
# 20405
#   availability_365 neighbourhood_group    id
# 0               1M               Bronx    66
# 1               1M            Brooklyn  1778
# 2               1M           Manhattan  1758
# 3               1M              Queens   334
# 4               1M       Staten Island    10

# %%
fig = px.scatter(availability, y='availability_365', x='id', 
                 color= 'neighbourhood_group',symbol = 'neighbourhood_group',
                 title= 'Neighbourhood Group -Month wise -Bookings Count',
                 labels={"id: No of Bookings"} )
fig.update_traces(marker_size=12)
fig.update_layout(xaxis_title="Count of Bookings",
                  yaxis_title="No of months the listings are available for booking")
fig.show()



fig = px.scatter(availability, y='neighbourhood_group', x='id', 
                 symbol= 'availability_365',color = 'availability_365',
                title= 'Neighbourhood Group -Month wise -Bookings Count')
fig.update_traces(marker_size=15)
fig.update_layout(xaxis_title="Count of Bookings",
                  yaxis_title="Neighbourhood Group")
fig.show()
# Out:
# <div>                            <div id="48eb3fb0-8f8d-4a57-916e-7edd4a5c9b9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48eb3fb0-8f8d-4a57-916e-7edd4a5c9b9e")) {                    Plotly.newPlot(                        "48eb3fb0-8f8d-4a57-916e-7edd4a5c9b9e",                        [{"hovertemplate":"neighbourhood_group=Bronx<br>id=%{x}<br>availability_365=%{y}<extra></extra>","legendgroup":"Bronx","marker":{"color":"#636efa","symbol":"circle","size":12},"mode":"markers","name":"Bronx","orientation":"h","showlegend":true,"x":[66,69,89,26,41,62,25,18,29,34,72,153],"xaxis":"x","y":["1M","2M","3M","4M","5M","6M","7M","8M","9M","10M","11M","12M"],"yaxis":"y","type":"scatter"},{"hovertemplate":"neighbourhood_group=Brooklyn<br>id=%{x}<br>availabil
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Dot plots is chose when the number of categories in a grouped abr plot is high. Here, the categories are 12 for availability_365 and 5 for neighbour hood group. hence dot plot is chosen

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - In all the months the numbers of bookings in Manhattan and Brooklyn is high, followed by Queens
# - Manhattan & Brooklyn booking availability follow the pattern of 1 M as the highest, followed by 12M(through out the year), next by 3M and 6M (half an year)
# - Majority of bookings in Queens is through the year listings, followedd by 3M
# - The 12m listings of Queens is comparable to that of Manhattan and Brooklyn, the 3M,1M and 6M listings are very less

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - 1M listings of Queens can be improved to attract more visitors like Manhattan & Brooklyn

# %% [markdown]
# #### Chart - 11 Effect of Room type on price range

# %%
# Chart - 10 visualization code

# %%
print(len(bookings))
print(bookings['price'].isnull().sum())
# Out:
# 20405
# 0

# %%
rt_pr = pd.DataFrame(bookings.groupby(['room_type','price'])['id'].apply(lambda x:len(x))).reset_index()
rt_pr.dropna(inplace = True)
print(sum(rt_pr['id']))
rt_pr.head()
# Out:
# 20405
#      room_type       price    id
# 0  Entire Home     (0, 50]    70
# 1  Entire Home   (50, 100]  1763
# 2  Entire Home  (100, 150]  3054
# 3  Entire Home  (150, 200]  2563
# 4  Entire Home  (200, 250]  1305

# %%
bookings.groupby(['room_type'])['id'].apply(lambda x:len(x))
# Out:
# room_type
# Entire Home      9729
# Private room    10108
# Shared room       568
# Name: id, dtype: int64

# %%
fig = px.bar(rt_pr, x="room_type", y="id", color="price", title="Roomtype-Price on Bookings",text_auto =True)
#fig = px.bar(rt_pr, x="price", y="id", color="room_type", title="Roomtype-Price on Bookings")
fig.show()
# Out:
# <div>                            <div id="a700854d-f492-4d0d-8b1d-8493565cbec9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a700854d-f492-4d0d-8b1d-8493565cbec9")) {                    Plotly.newPlot(                        "a700854d-f492-4d0d-8b1d-8493565cbec9",                        [{"alignmentgroup":"True","hovertemplate":"price=(0, 50]<br>room_type=%{x}<br>id=%{y}<extra></extra>","legendgroup":"(0, 50]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"(0, 50]","offsetgroup":"(0, 50]","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Entire Home","Private room","Shared room"],"xaxis":"x","y":[70,2191,339],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"price=(50, 100]<br>roo
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked bar is also simialr way of representing like dot plots, used whent the categories of bar plot is high

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Given the cost advantage renting a private room for cheaper price like (0.50],(50,100],(100,150] more bookings are done in this price range
# - Although the bookings for private rooms is higher for cheaper prices, the overall bookings for entire home (9983) and private room (10136) remain in a similar range
# - Shared room the price ranges for bookings done is very low. and the number bookings done is also low.
# -

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, to determine the pricing of the rooms

# %% [markdown]
# #### Chart - 12 What is the price range in each neighbourhood group

# %%
# Chart - 11 visualization code

# %%
pr_ng =pd.DataFrame(bookings.groupby(['neighbourhood_group','price'])['id'].apply(lambda x:len(x))).reset_index()
pr_ng.dropna(inplace=True)
pr_ng.head()
# Out:
#   neighbourhood_group       price     id
# 0               Bronx     (0, 50]  240.0
# 1               Bronx   (50, 100]  314.0
# 2               Bronx  (100, 150]   96.0
# 3               Bronx  (150, 200]   19.0
# 4               Bronx  (200, 250]    7.0

# %%
fig =px.bar(pr_ng, x="neighbourhood_group", y="id", color="price", title="Neighbourhood-Price on Bookings",text_auto =True)
fig.show()
# Out:
# <div>                            <div id="f0d7508f-d537-4a33-bf57-c273833f680e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d7508f-d537-4a33-bf57-c273833f680e")) {                    Plotly.newPlot(                        "f0d7508f-d537-4a33-bf57-c273833f680e",                        [{"alignmentgroup":"True","hovertemplate":"price=(0, 50]<br>neighbourhood_group=%{x}<br>id=%{y}<extra></extra>","legendgroup":"(0, 50]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"(0, 50]","offsetgroup":"(0, 50]","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bronx","Brooklyn","Manhattan","Queens","Staten Island"],"xaxis":"x","y":[240.0,1243.0,314.0,732.0,71.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked bar is also simialr way of representing like dot plots, used whent the categories of bar plot is high

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - brooklyn and Manhattan are the major locations where teh bookings are higher
# - In both these locations, more than 50% of the visitors pay a price range between 0-150. [(0,50],(50,100],(100,150])
# - Next set of customers are willing to pay a price between (150,200]
# - Only limited visitors pay a premium price than teh above

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, to determine the price range of the onboarding hotel/room

# %% [markdown]
# #### Chart - 13  Does reviews about the listing haev an effect on the price?

# %%
# Chart - 12 visualization code
pr_r =pd.DataFrame(bookings.groupby(['reviews_per_month','price'])['id'].apply(lambda x:len(x))).reset_index()
pr_r.dropna(inplace=True)
pr_r.head()
# Out:
#   reviews_per_month       price      id
# 0            (0, 1]     (0, 50]   982.0
# 1            (0, 1]   (50, 100]  3007.0
# 2            (0, 1]  (100, 150]  1684.0
# 3            (0, 1]  (150, 200]  1187.0
# 4            (0, 1]  (200, 250]   609.0

# %%
#sns.barplot(data =pr_r, x = 'reviews_per_month', y='id', hue ='price')

sns.catplot(
    data =pr_r, kind="bar",
    x='reviews_per_month', y='id', col='price',
    height=4, aspect=.5,
)
# Out:
# C:\Users\hornt\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
bookings['latitude'][0]
# Out:
# 40.64749

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Instead of stacked bar chart, this kind of separate plots with column grid, helps in betetr visualisation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  No of reviews given in total is higher for '((50,100],(100,150],(150,200], (0,50])'
#  Irrespective of the price range, in each of the grid, the number of reviews per month is in
# decreasing order with 1 reviews as the most, followed by 2 till 6

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [raw]
# Not much of use

# %% [markdown]
# #####  Chart 13 -Plotting Latitude Longitude of the locations

# %%
plt.figure(figsize=(7,5))
plt.scatter(bookings['latitude'],bookings['longitude'], s =1, marker ='.', color ='red')
plt.xlabel('Latitude',weight ='bold',size=10)
plt.ylabel('Longitude',weight ='bold',size =10)
plt.title('Latitide-Longitude of AirBnb Listing',weight ='bold',size=10)
plt.show()

# %%
import plotly.express as px

# Create a choropleth map
fig = px.scatter_geo(data_frame=bookings, lat='latitude',  lon='longitude', color ='price')
fig.show()
# Out:
# <div>                            <div id="84ed30f2-1c61-45b3-94c3-3185f08fa9f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84ed30f2-1c61-45b3-94c3-3185f08fa9f0")) {                    Plotly.newPlot(                        "84ed30f2-1c61-45b3-94c3-3185f08fa9f0",                        [{"geo":"geo","hovertemplate":"price=(100, 150]<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>","lat":[40.64749,40.71344,40.80316,40.70837,40.74192,40.68069,40.68001,40.68371,40.66278,40.69673,40.79009,40.81175,40.74771,40.68111,40.73506,40.72004,40.68346,40.74138,40.71154,40.65401,40.71833,40.68233,40.70093,40.79764,40.68413,40.71332,40.68698,40.7288,40.778,40.81618,40.71341,40.76754,40.68296,40.6863,40.74028,40.68281,40.71536,40.71363,40.68306,40.71045,40
# ...

# %%
# import gmplot package 
import gmplot 
  
# GoogleMapPlotter return Map object 
# Pass the center latitude and 
# center longitude 
gmap1 = gmplot.GoogleMapPlotter(bookings['latitude'][0],bookings['longitude'][0], 13 ) 


gmap1.heatmap( bookings['latitude'], bookings['longitude'] ) 
#gmap1.plot(bookings['latitude'], bookings['longitude'],'cornflowerblue', edge_width = 2.5) 
  
# Pass the absolute path 
#gmap1.draw( "C:\\Users\\hornt\\Desktop\\map.html" )

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Visualising the locations of the Airbnb listings. It helps to visually see the clusters and price range of listings in different location

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, to see the price range in most booked locations and adjust the other pricings accordingly

# %% [markdown]
# #### Chart - 14 - Does the price change based on room_type and neighbourhood?

# %%
# Chart - 13 visualization code

# %%
fig = px.icicle(bookings, path=[px.Constant("Region- RoomType - Price"), 'neighbourhood_group', 'room_type', 'price'], values='count_booking')
fig.update_traces(root_color="lightgrey")
fig.show()
# Out:
# <div>                            <div id="2e188a47-4448-43ca-999d-9d1551f7a42a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e188a47-4448-43ca-999d-9d1551f7a42a")) {                    Plotly.newPlot(                        "2e188a47-4448-43ca-999d-9d1551f7a42a",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_booking=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Region- RoomType - Price/Bronx/Entire Home/(0, 50]","Region- RoomType - Price/Brooklyn/Entire Home/(0, 50]","Region- RoomType - Price/Manhattan/Entire Home/(0, 50]","Region- RoomType - Price/Queens/Entire Home/(0, 50]","Region- RoomType - Price/Staten Island/Entire Home/(0, 50]","Region- 
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Icicile charts/ Tree charts are important to visualise a series of variables and their dependencies. Here, relation of Region-RoomType-Price is visualised in icicle Charts

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - In the top 3 regions (Manhattan, brooklyn, Queens), the room types (private room and the entire hoom) are equally booked, while the shared room is not much preferred.
# - In Brooklyn , the price ranges from (50-100],(100,150],(150,200]
# - In Manhattan, the preferred price range is (50,100] followed by (150,200]
# - In Queens, the preferred price range is (50,100]

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, in determining and adjusting the price ranges across rooms in a particular region

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
bookings.columns
# Out:
# Index(['id', 'name', 'host_id', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'count_booking'],
#       dtype='object')

# %%
print(bookings.select_dtypes(include =['int','float']).columns)

corr_df = pd.get_dummies(bookings[['price','room_type','minimum_nights','neighbourhood_group']])
#corr_df.corr()
plt.figure(figsize =(25,25))
sns.heatmap(corr_df.corr(),annot =True ,fmt ='0.1f')
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'minimum_nights',
#        'number_of_reviews', 'calculated_host_listings_count', 'count_booking'],
#       dtype='object')
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# correlation maps are used to identify relationships between numerical variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not much, since a relation between categorical variable also need to considered

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# - Increase more hotel listings in the price range  0-200.
# - Increase more listings in the room type -Private Room or Entire Home
# - Increase more listing that are availabled throughout the year, for 6 months.
# - Usual booking period is between 1-3 nights.
#
# - Increase the listings in regions like Queens, Staten Island, bronx by considering the above mentioned criteria.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# I've performed Exploratory Data Analysis on Airbnb data using Python. Based on the analysis, I suugest the solutions  mentioned above section - (suggestion to achieve business objective) to generate more revenue and increase the bookings, of Airbnb

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
